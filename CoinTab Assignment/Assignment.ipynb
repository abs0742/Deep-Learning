# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

# %%
order_report = pd.read_excel('Company X - Order Report.xlsx')

# %%
order_report
# Out:
#      ExternOrderNo            SKU  Order Qty
# 0       2001827036  8904223818706        1.0
# 1       2001827036  8904223819093        1.0
# 2       2001827036  8904223819109        1.0
# 3       2001827036  8904223818430        1.0
# 4       2001827036  8904223819277        1.0
# ..             ...            ...        ...
# 395     2001806229  8904223818942        1.0
# 396     2001806229  8904223818850        1.0
# 397     2001806226  8904223818850        2.0
# 398     2001806210  8904223816214        1.0
# 399     2001806210  8904223818874        1.0
#
# [400 rows x 3 columns]

# %%
invoice_data = pd.read_excel('Courier Company - Invoice.xlsx')
SKU = pd.read_excel('Company X - SKU Master.xlsx')
pincode = pd.read_excel('Company X - Pincode Zones.xlsx')
rates = pd.read_excel('Courier Company - Rates.xlsx')

# %%
invoice_data.head()
# Out:
#         AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0  1091117222124  2001806232            1.30             121003
# 1  1091117222194  2001806273            1.00             121003
# 2  1091117222931  2001806408            2.50             121003
# 3  1091117223244  2001806458            1.00             121003
# 4  1091117229345  2001807012            0.15             121003
#
#    Customer Pincode Zone Type of Shipment  Billing Amount (Rs.)
# 0            507101    d  Forward charges                 135.0
# 1            486886    d  Forward charges                  90.2
# 2            532484    d  Forward charges                 224.6
# 3            143001    b  Forward charges                  61.3
# 4            515591    d  Forward charges                  45.4

# %%
SKU.head()
# Out:
#              SKU  Weight (g)
# 0  8904223815682         210
# 1  8904223815859         165
# 2  8904223815866         113
# 3  8904223815873          65
# 4  8904223816214         120

# %%
pincode.head()
# Out:
#    Warehouse Pincode  Customer Pincode Zone
# 0             121003            507101    d
# 1             121003            486886    d
# 2             121003            532484    d
# 3             121003            143001    b
# 4             121003            515591    d

# %%
rates.head()
# Out:
#    fwd_a_fixed  fwd_a_additional  fwd_b_fixed  fwd_b_additional  fwd_c_fixed  \
# 0         29.5              23.6           33              28.3         40.1
#
#    fwd_c_additional  fwd_d_fixed  fwd_d_additional  fwd_e_fixed  \
# 0              38.9         45.4              44.8         56.6
#
#    fwd_e_additional  rto_a_fixed  rto_a_additional  rto_b_fixed  \
# 0              55.5         13.6              23.6         20.5
#
#    rto_b_additional  rto_c_fixed  rto_c_additional  rto_d_fixed  \
# 0              28.3         31.9              38.9         41.3
#
#    rto_d_additional  rto_e_fixed  rto_e_additional
# 0              44.8         50.7              55.5

# %% [markdown]
# ## Perform basic data quality check

# %%
order_report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ExternOrderNo  400 non-null    int64
#  1   SKU            400 non-null    object
#  2   Order Qty      400 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 9.5+ KB

# %%
order_report.duplicated().sum()
# Out:
# 2

# %%
invoice_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   AWB Code              124 non-null    int64
#  1   Order ID              124 non-null    int64
#  2   Charged Weight        124 non-null    float64
#  3   Warehouse Pincode     124 non-null    int64
#  4   Customer Pincode      124 non-null    int64
#  5   Zone                  124 non-null    object
#  6   Type of Shipment      124 non-null    object
#  7   Billing Amount (Rs.)  124 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 7.9+ KB

# %%
invoice_data.duplicated().sum()
# Out:
# 0

# %%
SKU.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SKU         66 non-null     object
#  1   Weight (g)  66 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.2+ KB

# %%
SKU.duplicated().sum()
# Out:
# 1

# %%
SKU.drop_duplicates(subset='SKU', inplace=True)

# %%
SKU.duplicated().sum()
# Out:
# 0

# %%
pincode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Warehouse Pincode  124 non-null    int64
#  1   Customer Pincode   124 non-null    int64
#  2   Zone               124 non-null    object
# dtypes: int64(2), object(1)
# memory usage: 3.0+ KB

# %%
pincode.duplicated().sum()
# Out:
# 16

# %%
pincode.drop_duplicates(subset='Customer Pincode', inplace=True)

# %%
pincode.duplicated().sum()
# Out:
# 0

# %%
rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fwd_a_fixed       1 non-null      float64
#  1   fwd_a_additional  1 non-null      float64
#  2   fwd_b_fixed       1 non-null      int64
#  3   fwd_b_additional  1 non-null      float64
#  4   fwd_c_fixed       1 non-null      float64
#  5   fwd_c_additional  1 non-null      float64
#  6   fwd_d_fixed       1 non-null      float64
#  7   fwd_d_additional  1 non-null      float64
#  8   fwd_e_fixed       1 non-null      float64
#  9   fwd_e_additional  1 non-null      float64
#  10  rto_a_fixed       1 non-null      float64
#  11  rto_a_additional  1 non-null      float64
#  12  rto_b_fixed       1 non-null      float64
#  13  rto_b_additional  1 non-null      float64
#  14  rto_c_fixed       1 non-null      float64
#  15  rto_c_additional  1 non-null      float64
# ...

# %%
rates.duplicated().sum()
# Out:
# 0

# %%
df = pd.DataFrame()
df[["Order ID", "AWB No."]] = invoice_data[["Order ID", "AWB Code"]].copy()

# %%
df.head()
# Out:
#      Order ID        AWB No.
# 0  2001806232  1091117222124
# 1  2001806273  1091117222194
# 2  2001806408  1091117222931
# 3  2001806458  1091117223244
# 4  2001807012  1091117229345

# %%
order_sku = order_report.merge(SKU, on='SKU', how='inner')

# %%
order_sku.head()
# Out:
#    ExternOrderNo            SKU  Order Qty  Weight (g)
# 0     2001827036  8904223818706        1.0         127
# 1     2001827036  8904223819093        1.0         150
# 2     2001827036  8904223819109        1.0         100
# 3     2001827036  8904223818430        1.0         165
# 4     2001827036  8904223819277        1.0         350

# %%
order_sku['Per Wt'] = order_sku['Order Qty']*order_sku['Weight (g)']

# %%
order_sku
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)  Per Wt
# 0       2001827036  8904223818706        1.0         127   127.0
# 1       2001827036  8904223819093        1.0         150   150.0
# 2       2001827036  8904223819109        1.0         100   100.0
# 3       2001827036  8904223818430        1.0         165   165.0
# 4       2001827036  8904223819277        1.0         350   350.0
# ..             ...            ...        ...         ...     ...
# 395     2001806229  8904223818942        1.0         133   133.0
# 396     2001806229  8904223818850        1.0         240   240.0
# 397     2001806226  8904223818850        2.0         240   480.0
# 398     2001806210  8904223816214        1.0         120   120.0
# 399     2001806210  8904223818874        1.0         100   100.0
#
# [400 rows x 5 columns]

# %%
order_sku.groupby('ExternOrderNo')['Per Wt'].sum().to_frame()
# Out:
#                Per Wt
# ExternOrderNo
# 2001806210      220.0
# 2001806226      480.0
# 2001806229      500.0
# 2001806232     1302.0
# 2001806233      245.0
# ...               ...
# 2001821995      477.0
# 2001822466     1376.0
# 2001823564      672.0
# 2001825261     1557.0
# 2001827036     1676.0
#
# [124 rows x 1 columns]

# %%
order_sku[order_sku['ExternOrderNo']==2001823564]
# Out:
#     ExternOrderNo            SKU  Order Qty  Weight (g)  Per Wt
# 13     2001823564  8904223819291        2.0         112   224.0
# 14     2001823564  8904223819031        2.0         112   224.0
# 15     2001823564  8904223819024        2.0         112   224.0

# %%
df = df.merge(order_sku.groupby('ExternOrderNo')['Per Wt'].sum().to_frame(), left_on='Order ID', right_on="ExternOrderNo")

# %%
df['Total Weight as per X(KG)'] = df['Per Wt']/1000

# %%
df.head()
# Out:
#      Order ID        AWB No.  Per Wt  Total Weight as per X(KG)
# 0  2001806232  1091117222124  1302.0                      1.302
# 1  2001806273  1091117222194   615.0                      0.615
# 2  2001806408  1091117222931  2265.0                      2.265
# 3  2001806458  1091117223244   700.0                      0.700
# 4  2001807012  1091117229345   240.0                      0.240

# %%
df = df.drop(columns=['Per Wt'])

# %%
df['Weight slab as per X(KG)'] = np.ceil(df['Total Weight as per X(KG)']*2)/2

# %%
df.head()
# Out:
#      Order ID        AWB No.  Total Weight as per X(KG)  \
# 0  2001806232  1091117222124                      1.302
# 1  2001806273  1091117222194                      0.615
# 2  2001806408  1091117222931                      2.265
# 3  2001806458  1091117223244                      0.700
# 4  2001807012  1091117229345                      0.240
#
#    Weight slab as per X(KG)
# 0                       1.5
# 1                       1.0
# 2                       2.5
# 3                       1.0
# 4                       0.5

# %%
df = df.merge(invoice_data[['Charged Weight', 'AWB Code']], left_on= 'AWB No.', right_on="AWB Code")

# %%
df.head()
# Out:
#      Order ID        AWB No.  Total Weight as per X(KG)  \
# 0  2001806232  1091117222124                      1.302
# 1  2001806273  1091117222194                      0.615
# 2  2001806408  1091117222931                      2.265
# 3  2001806458  1091117223244                      0.700
# 4  2001807012  1091117229345                      0.240
#
#    Weight slab as per X(KG)  Charged Weight       AWB Code
# 0                       1.5            1.30  1091117222124
# 1                       1.0            1.00  1091117222194
# 2                       2.5            2.50  1091117222931
# 3                       1.0            1.00  1091117223244
# 4                       0.5            0.15  1091117229345

# %%
df.rename({'Charged Weight': 'Total weight as per Courier Company(KG)'}, axis=1, inplace=True)

# %%
df.head()
# Out:
#      Order ID        AWB No.  Total Weight as per X(KG)  \
# 0  2001806232  1091117222124                      1.302
# 1  2001806273  1091117222194                      0.615
# 2  2001806408  1091117222931                      2.265
# 3  2001806458  1091117223244                      0.700
# 4  2001807012  1091117229345                      0.240
#
#    Weight slab as per X(KG)  Total weight as per Courier Company(KG)  \
# 0                       1.5                                     1.30
# 1                       1.0                                     1.00
# 2                       2.5                                     2.50
# 3                       1.0                                     1.00
# 4                       0.5                                     0.15
#
#         AWB Code
# 0  1091117222124
# 1  1091117222194
# 2  1091117222931
# 3  1091117223244
# 4  1091117229345

# %%
df['Weight slab charged by Courier Company(KG)']=np.ceil(df['Total weight as per Courier Company(KG)']*2)/2

# %%
df.head()
# Out:
#      Order ID        AWB No.  Total Weight as per X(KG)  \
# 0  2001806232  1091117222124                      1.302
# 1  2001806273  1091117222194                      0.615
# 2  2001806408  1091117222931                      2.265
# 3  2001806458  1091117223244                      0.700
# 4  2001807012  1091117229345                      0.240
#
#    Weight slab as per X(KG)  Total weight as per Courier Company(KG)  \
# 0                       1.5                                     1.30
# 1                       1.0                                     1.00
# 2                       2.5                                     2.50
# 3                       1.0                                     1.00
# 4                       0.5                                     0.15
#
#         AWB Code  Weight slab charged by Courier Company(KG)
# 0  1091117222124                                         1.5
# 1  1091117222194                                         1.0
# ...

# %%
df.head()
# Out:
#      Order ID        AWB No.  Total Weight as per X(KG)  \
# 0  2001806232  1091117222124                      1.302
# 1  2001806273  1091117222194                      0.615
# 2  2001806408  1091117222931                      2.265
# 3  2001806458  1091117223244                      0.700
# 4  2001807012  1091117229345                      0.240
#
#    Weight slab as per X(KG)  Total weight as per Courier Company(KG)  \
# 0                       1.5                                     1.30
# 1                       1.0                                     1.00
# 2                       2.5                                     2.50
# 3                       1.0                                     1.00
# 4                       0.5                                     0.15
#
#         AWB Code  Weight slab charged by Courier Company(KG)
# 0  1091117222124                                         1.5
# 1  1091117222194                                         1.0
# ...

# %%
invoice1 = invoice_data.merge(pincode, on=['Customer Pincode', 'Warehouse Pincode'], how='right')

# %%
invoice1.head()
# Out:
#         AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0  1091117222124  2001806232            1.30             121003
# 1  1091117222194  2001806273            1.00             121003
# 2  1091117222931  2001806408            2.50             121003
# 3  1091117223244  2001806458            1.00             121003
# 4  1091117229345  2001807012            0.15             121003
#
#    Customer Pincode Zone_x Type of Shipment  Billing Amount (Rs.) Zone_y
# 0            507101      d  Forward charges                 135.0      d
# 1            486886      d  Forward charges                  90.2      d
# 2            532484      d  Forward charges                 224.6      d
# 3            143001      b  Forward charges                  61.3      b
# 4            515591      d  Forward charges                  45.4      d

# %%
df = df.merge(invoice1[['Zone_y', 'AWB Code']],on='AWB Code')

# %%
df.head()
# Out:
#      Order ID        AWB No.  Total Weight as per X(KG)  \
# 0  2001806232  1091117222124                      1.302
# 1  2001806273  1091117222194                      0.615
# 2  2001806408  1091117222931                      2.265
# 3  2001806458  1091117223244                      0.700
# 4  2001807012  1091117229345                      0.240
#
#    Weight slab as per X(KG)  Total weight as per Courier Company(KG)  \
# 0                       1.5                                     1.30
# 1                       1.0                                     1.00
# 2                       2.5                                     2.50
# 3                       1.0                                     1.00
# 4                       0.5                                     0.15
#
#         AWB Code  Weight slab charged by Courier Company(KG) Zone_y
# 0  1091117222124                                         1.5      d
# 1  1091117222194                                         1.0      d
# ...

# %%
df.rename({'Zone_y':'Delivery Zone as per X'}, axis=1, inplace=True)

# %%
df.shape
# Out:
# (124, 8)

# %%
df = df.merge(invoice1[['Zone_x', 'AWB Code']], on='AWB Code')

# %%
df.rename({'Zone_x':'Delivery Zone charged by Courier Company'}, axis=1, inplace=True)

# %%
df.shape
# Out:
# (124, 9)

# %%
df
# Out:
#        Order ID        AWB No.  Total Weight as per X(KG)  \
# 0    2001806232  1091117222124                      1.302
# 1    2001806273  1091117222194                      0.615
# 2    2001806408  1091117222931                      2.265
# 3    2001806458  1091117223244                      0.700
# 4    2001807012  1091117229345                      0.240
# ..          ...            ...                        ...
# 119  2001812941  1091118551656                      0.500
# 120  2001809383  1091117614452                      0.607
# 121  2001820978  1091120922803                      0.515
# 122  2001811475  1091121844806                      0.689
# 123  2001811305  1091121846136                      0.750
#
#      Weight slab as per X(KG)  Total weight as per Courier Company(KG)  \
# 0                         1.5                                     1.30
# 1                         1.0                                     1.00
# ...

# %%
df.shape
# Out:
# (124, 9)

# %%
df.head()
# Out:
#      Order ID        AWB No.  Total Weight as per X(KG)  \
# 0  2001806232  1091117222124                      1.302
# 1  2001806273  1091117222194                      0.615
# 2  2001806408  1091117222931                      2.265
# 3  2001806458  1091117223244                      0.700
# 4  2001807012  1091117229345                      0.240
#
#    Weight slab as per X(KG)  Total weight as per Courier Company(KG)  \
# 0                       1.5                                     1.30
# 1                       1.0                                     1.00
# 2                       2.5                                     2.50
# 3                       1.0                                     1.00
# 4                       0.5                                     0.15
#
#         AWB Code  Weight slab charged by Courier Company(KG)  \
# 0  1091117222124                                         1.5
# 1  1091117222194                                         1.0
# ...

# %%
invoice_data['Type of Shipment'].value_counts()
# Out:
# Type of Shipment
# Forward charges            109
# Forward and RTO charges     15
# Name: count, dtype: int64

# %%
invoice_data[['Billing Amount (Rs.)', 'Zone', 'Charged Weight']][invoice_data['Type of Shipment']=='Forward and RTO charges']
# Out:
#      Billing Amount (Rs.) Zone  Charged Weight
# 18                  107.3    e            0.20
# 22                  172.8    d            0.70
# 23                  102.3    b            0.60
# 24                  172.8    d            0.99
# 25                  172.8    d            0.70
# 26                  213.5    e            0.80
# 27                  258.9    d            1.20
# 28                  151.1    b            1.30
# 29                  172.8    d            0.70
# 30                  345.0    d            1.60
# 31                  258.9    d            1.13
# 32                  172.8    d            0.60
# 69                   86.7    d            0.50
# 73                   86.7    d            0.15
# 120                  86.7    d            0.50

# %%
for i in rates.columns:
    t = '{}={}'.format(i, rates[i][0])
    exec(t)
    print(i)
# Out:
# fwd_a_fixed
# fwd_a_additional
# fwd_b_fixed
# fwd_b_additional
# fwd_c_fixed
# fwd_c_additional
# fwd_d_fixed
# fwd_d_additional
# fwd_e_fixed
# fwd_e_additional
# rto_a_fixed
# rto_a_additional
# rto_b_fixed
# rto_b_additional
# rto_c_fixed
# rto_c_additional
# rto_d_fixed
# rto_d_additional
# rto_e_fixed
# rto_e_additional

# %%
fwd_a_fixed
# Out:
# 29.5

# %%
temp = invoice1.merge(df[['Weight slab as per X(KG)', 'AWB Code']], on='AWB Code')

# %%
temp
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091117904860  2001811039            0.68             121003
# 120  1091121846136  2001811305            0.50             121003
# 121  1091118551656  2001812941            0.73             121003
# 122  1091117614452  2001809383            0.50             121003
# 123  1091120922803  2001820978            0.50             121003
#
#      Customer Pincode Zone_x         Type of Shipment  Billing Amount (Rs.)  \
# 0              507101      d          Forward charges                 135.0
# ...

# %%
temp.dtypes
# Out:
# AWB Code                      int64
# Order ID                      int64
# Charged Weight              float64
# Warehouse Pincode             int64
# Customer Pincode              int64
# Zone_x                       object
# Type of Shipment             object
# Billing Amount (Rs.)        float64
# Zone_y                       object
# Weight slab as per X(KG)    float64
# dtype: object

# %%
def Calc(x):
    x=x.tolist()
    #print(x)
    if x[2]=='Forward charges':
        if x[0]=='a':
            return fwd_a_fixed+((np.ceil(x[1]/0.5)-1)*fwd_a_additional)
        elif x[0]=='b':
            return fwd_b_fixed+((np.ceil(x[1]/0.5)-1)*fwd_b_additional)
        elif x[0]=='c':
            return fwd_c_fixed+((np.ceil(x[1]/0.5)-1)*fwd_c_additional)
        elif x[0]=='d':
            return fwd_d_fixed+((np.ceil(x[1]/0.5)-1)*fwd_d_additional)
        else:
            return fwd_e_fixed+((np.ceil(x[1]/0.5)-1)*fwd_e_additional)
    else:
        if x[0]=='a':
            return fwd_a_fixed+((np.ceil(x[1]/0.5)-1)*fwd_a_additional)+rto_a_fixed+((np.ceil(x[1]/0.5)-1)*rto_a_additional)
        elif x[0]=='b':
            return fwd_b_fixed+((np.ceil(x[1]/0.5)-1)*fwd_a_additional)+rto_b_fixed+((np.ceil(x[1]/0.5)-1)*rto_a_additional)
        elif x[0]=='c':
            return fwd_c_fixed+((np.ceil(x[1]/0.5)-1)*fwd_a_additional)+rto_c_fixed+((np.ceil(x[1]/0.5)-1)*rto_a_additional)
        elif x[0]=='d':
            return fwd_d_fixed+((np.ceil(x[1]/0.5)-1)*fwd_a_additional)+rto_d_fixed+((np.ceil(x[1]/0.5)-1)*rto_a_additional)
        else:
            return fwd_e_fixed+((np.ceil(x[1]/0.5)-1)*fwd_a_additional)+rto_e_fixed+((np.ceil(x[1]/0.5)-1)*rto_a_additional)

# %%
temp['Expected Charge as per X (Rs.)']=temp[['Zone_y', 'Weight slab as per X(KG)', 'Type of Shipment']].apply(Calc, axis=1)

# %%
temp
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091117904860  2001811039            0.68             121003
# 120  1091121846136  2001811305            0.50             121003
# 121  1091118551656  2001812941            0.73             121003
# 122  1091117614452  2001809383            0.50             121003
# 123  1091120922803  2001820978            0.50             121003
#
#      Customer Pincode Zone_x         Type of Shipment  Billing Amount (Rs.)  \
# 0              507101      d          Forward charges                 135.0
# ...

# %%
df = df.merge(temp[['Expected Charge as per X (Rs.)', 'AWB Code']], on='AWB Code')

# %%
df.head()
# Out:
#      Order ID        AWB No.  Total Weight as per X(KG)  \
# 0  2001806232  1091117222124                      1.302
# 1  2001806273  1091117222194                      0.615
# 2  2001806408  1091117222931                      2.265
# 3  2001806458  1091117223244                      0.700
# 4  2001807012  1091117229345                      0.240
#
#    Weight slab as per X(KG)  Total weight as per Courier Company(KG)  \
# 0                       1.5                                     1.30
# 1                       1.0                                     1.00
# 2                       2.5                                     2.50
# 3                       1.0                                     1.00
# 4                       0.5                                     0.15
#
#         AWB Code  Weight slab charged by Courier Company(KG)  \
# 0  1091117222124                                         1.5
# 1  1091117222194                                         1.0
# ...

# %%
temp=temp.merge(df[['Weight slab charged by Courier Company(KG)', 'AWB Code']], on='AWB Code')

# %%
temp.shape
# Out:
# (124, 12)

# %%
invoice_data
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091118551656  2001812941            0.73             121003
# 120  1091117614452  2001809383            0.50             121003
# 121  1091120922803  2001820978            0.50             121003
# 122  1091121844806  2001811475            0.50             121003
# 123  1091121846136  2001811305            0.50             121003
#
#      Customer Pincode Zone         Type of Shipment  Billing Amount (Rs.)
# 0              507101    d          Forward charges                 135.0
# ...

# %%
df = df.merge(invoice_data[['Billing Amount (Rs.)', 'AWB Code']], on='AWB Code')

# %%
df.rename({'Billing Amount (Rs.)':'Charged Billed by Courier Company(Rs.)'}, inplace=True, axis=1)

# %%
df
# Out:
#        Order ID        AWB No.  Total Weight as per X(KG)  \
# 0    2001806232  1091117222124                      1.302
# 1    2001806273  1091117222194                      0.615
# 2    2001806408  1091117222931                      2.265
# 3    2001806458  1091117223244                      0.700
# 4    2001807012  1091117229345                      0.240
# ..          ...            ...                        ...
# 119  2001812941  1091118551656                      0.500
# 120  2001809383  1091117614452                      0.607
# 121  2001820978  1091120922803                      0.515
# 122  2001811475  1091121844806                      0.689
# 123  2001811305  1091121846136                      0.750
#
#      Weight slab as per X(KG)  Total weight as per Courier Company(KG)  \
# 0                         1.5                                     1.30
# 1                         1.0                                     1.00
# ...

# %%
df.shape
# Out:
# (124, 11)

# %%
df['Difference Between Expected Charges and billed Charges(Rs.)']=df['Expected Charge as per X (Rs.)']-df['Charged Billed by Courier Company(Rs.)']

# %%
df.shape
# Out:
# (124, 12)

# %%
df.head()
# Out:
#      Order ID        AWB No.  Total Weight as per X(KG)  \
# 0  2001806232  1091117222124                      1.302
# 1  2001806273  1091117222194                      0.615
# 2  2001806408  1091117222931                      2.265
# 3  2001806458  1091117223244                      0.700
# 4  2001807012  1091117229345                      0.240
#
#    Weight slab as per X(KG)  Total weight as per Courier Company(KG)  \
# 0                       1.5                                     1.30
# 1                       1.0                                     1.00
# 2                       2.5                                     2.50
# 3                       1.0                                     1.00
# 4                       0.5                                     0.15
#
#         AWB Code  Weight slab charged by Courier Company(KG)  \
# 0  1091117222124                                         1.5
# 1  1091117222194                                         1.0
# ...

# %%
df.to_excel('Clean_Data.xlsx', index=False)

# %% [markdown]
# ## Summary Table

# %%
Summary = pd.DataFrame({' ' : ['Total orders where X has been correctly charged', 'Total order where X has been overcharged', 'Total orders where X has been undercharged'], 'Count': '', 'Amount(Rs.)': ''})

# %%
Summary.index=Summary[' ']

# %%
del Summary[' ']

# %%
Summary
# Out:
#                                                 Count Amount(Rs.)
#
# Total orders where X has been correctly charged
# Total order where X has been overcharged
# Total orders where X has been undercharged

# %%
Summary.loc[:]['Count'][0]=df['Difference Between Expected Charges and billed Charges(Rs.)'][df['Difference Between Expected Charges and billed Charges(Rs.)']==0].value_counts()[0]

# %%
Summary
# Out:
#                                                 Count Amount(Rs.)
#
# Total orders where X has been correctly charged    16
# Total order where X has been overcharged
# Total orders where X has been undercharged

# %%
Summary.loc[:]['Amount(Rs.)'][0]=df['Charged Billed by Courier Company(Rs.)'][df['Difference Between Expected Charges and billed Charges(Rs.)']==0].sum()

# %%
Summary
# Out:
#                                                 Count Amount(Rs.)
#
# Total orders where X has been correctly charged    16      1268.6
# Total order where X has been overcharged
# Total orders where X has been undercharged

# %%
Summary.loc[:]['Count'][1]=df['Difference Between Expected Charges and billed Charges(Rs.)'][df['Difference Between Expected Charges and billed Charges(Rs.)']<0].value_counts().sum()

# %%
Summary
# Out:
#                                                 Count Amount(Rs.)
#
# Total orders where X has been correctly charged    16      1268.6
# Total order where X has been overcharged           95
# Total orders where X has been undercharged

# %%
Summary.loc[:]['Amount(Rs.)'][1]=abs(df['Difference Between Expected Charges and billed Charges(Rs.)'][df['Difference Between Expected Charges and billed Charges(Rs.)']<0].sum())

# %%
Summary
# Out:
#                                                 Count Amount(Rs.)
#
# Total orders where X has been correctly charged    16      1268.6
# Total order where X has been overcharged           95      4957.2
# Total orders where X has been undercharged

# %%
Summary.loc[:]['Count'][2]=df['Difference Between Expected Charges and billed Charges(Rs.)'][df['Difference Between Expected Charges and billed Charges(Rs.)']>0].value_counts().sum()

# %%
Summary
# Out:
#                                                 Count Amount(Rs.)
#
# Total orders where X has been correctly charged    16      1268.6
# Total order where X has been overcharged           95      4957.2
# Total orders where X has been undercharged         13

# %%
Summary.loc[:]['Amount(Rs.)'][2]=abs(df['Difference Between Expected Charges and billed Charges(Rs.)'][df['Difference Between Expected Charges and billed Charges(Rs.)']>0].sum())

# %%
Summary
# Out:
#                                                 Count Amount(Rs.)
#
# Total orders where X has been correctly charged    16      1268.6
# Total order where X has been overcharged           95      4957.2
# Total orders where X has been undercharged         13       495.5

# %%
Summary.to_excel('Summary.xlsx')
